# %%
import pandas as pd

# %%
pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")
msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
hist = msft.history(period="1mo")

# %%
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-06-06 00:00:00-04:00  424.010010  425.309998  420.579987  424.519989
# 2024-06-07 00:00:00-04:00  426.200012  426.279999  423.000000  423.850006
# 2024-06-10 00:00:00-04:00  424.700012  428.079987  423.890015  427.869995
# 2024-06-11 00:00:00-04:00  425.480011  432.820007  425.250000  432.679993
# 2024-06-12 00:00:00-04:00  435.320007  443.399994  433.250000  441.059998
# 2024-06-13 00:00:00-04:00  440.850006  443.390015  439.369995  441.579987
# 2024-06-14 00:00:00-04:00  438.279999  443.140015  436.720001  442.570007
# 2024-06-17 00:00:00-04:00  442.589996  450.940002  440.720001  448.369995
# 2024-06-18 00:00:00-04:00  449.709991  450.140015  444.890015  446.339996
# 2024-06-20 00:00:00-04:00  446.299988  446.529999  441.269989  445.700012
# 2024-06-21 00:00:00-04:00  447.380005  450.579987  446.510010  449.779999
# 2024-06-24 00:00:00-04:00  449.799988  452.750000  446.410004  447.670013
# ...

# %%
msft.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'MSFT',
#  'exchangeName': 'NMS',
#  'fullExchangeName': 'NasdaqGS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 511108200,
#  'regularMarketTime': 1720209601,
#  'hasPrePostMarketData': True,
#  'gmtoffset': -14400,
#  'timezone': 'EDT',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 467.56,
#  'fiftyTwoWeekHigh': 468.35,
#  'fiftyTwoWeekLow': 458.965,
#  'regularMarketDayHigh': 468.35,
#  'regularMarketDayLow': 458.965,
#  'regularMarketVolume': 15662166,
#  'chartPreviousClose': 424.01,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EDT',
#    'start': 1720166400,
#    'end': 1720186200,
#    'gmtoffset': -14400},
#   'regular': {'timezone': 'EDT',
#    'start': 1720186200,
#    'end': 1720209600,
#    'gmtoffset': -14400},
#   'post': {'timezone': 'EDT',
#    'start': 1720209600,
#    'end': 1720224000,
#    'gmtoffset': -14400}},
#  'dataGranularity': '1d',
#  'range': '1mo',
# ...

# %%
msft.actions
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %%
msft.dividends
# Out:
# Series([], Name: Dividends, dtype: float64)

# %%
msft.splits
# Out:
# Series([], Name: Stock Splits, dtype: float64)

# %%
tickers = yf.Tickers('msft aapl goog')

# %%
import os

# %%
df = tickers.tickers['MSFT'].history(period = '5d')
df = pd.DataFrame(df)
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-06-28 00:00:00-04:00  453.070007  455.380005  446.410004  446.950012
# 2024-07-01 00:00:00-04:00  448.660004  457.369995  445.660004  456.730011
# 2024-07-02 00:00:00-04:00  453.200012  459.589996  453.109985  459.279999
# 2024-07-03 00:00:00-04:00  458.190002  461.019989  457.880005  460.769989
# 2024-07-05 00:00:00-04:00  459.609985  468.350006  458.970001  467.559998
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-06-28 00:00:00-04:00  28362300        0.0           0.0
# 2024-07-01 00:00:00-04:00  17662800        0.0           0.0
# 2024-07-02 00:00:00-04:00  13979800        0.0           0.0
# 2024-07-03 00:00:00-04:00   9932800        0.0           0.0
# 2024-07-05 00:00:00-04:00  15980200        0.0           0.0

# %%
import math
import numpy as np

# %%
df = df[['Open','High','Low','Close','Volume']]

# %%
df['Amplitude_de_preco'] = abs(df['High'] - df['Low'])
df['Volume'] = np.float64(df['Volume'])
df['Total_RS_negociado'] = df['Volume'] * df['Close']

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-06-28 00:00:00-04:00  453.070007  455.380005  446.410004  446.950012
# 2024-07-01 00:00:00-04:00  448.660004  457.369995  445.660004  456.730011
# 2024-07-02 00:00:00-04:00  453.200012  459.589996  453.109985  459.279999
# 2024-07-03 00:00:00-04:00  458.190002  461.019989  457.880005  460.769989
# 2024-07-05 00:00:00-04:00  459.609985  468.350006  458.970001  467.559998
#
#                                Volume  Amplitude_de_preco  Total_RS_negociado
# Date
# 2024-06-28 00:00:00-04:00  28362300.0            8.970001        1.267653e+10
# 2024-07-01 00:00:00-04:00  17662800.0           11.709991        8.067131e+09
# 2024-07-02 00:00:00-04:00  13979800.0            6.480011        6.420643e+09
# 2024-07-03 00:00:00-04:00   9932800.0            3.139984        4.576736e+09
# 2024-07-05 00:00:00-04:00  15980200.0            9.380005        7.471702e+09

# %%
root = f"C:\\Users\\marci\\OneDrive\\Desktop\\FIAP\\dev\\yfinance"

# %%
from datetime import date

str_date = date.today().strftime("%Y/%m/%d").replace('/','')
str_date
# Out:
# '20240706'

# %%
today_path = os.path.join(root, str_date)
os.path.exists(today_path)
# Out:
# False

# %%
# Out:
# 'C:\\Users\\marci\\OneDrive\\Desktop\\FIAP\\dev'
